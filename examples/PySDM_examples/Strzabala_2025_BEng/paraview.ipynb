# %% [markdown]
# [![preview notebook](https://img.shields.io/static/v1?label=render%20on&logo=github&color=87ce3e&message=GitHub)](https://github.com/open-atmos/PySDM/blob/main/examples/PySDM_examples/Strzabala_2025_BEng/paraview.ipynb)
# [![launch on mybinder.org](https://mybinder.org/badge_logo.svg)](https://mybinder.org/v2/gh/open-atmos/PySDM.git/main?urlpath=lab/tree/examples/PySDM_examples/Strzabala_2025_BEng/paraview.ipynb)
# [![launch on Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/open-atmos/PySDM/blob/main/examples/PySDM_examples/Strzabala_2025_BEng/paraview.ipynb)

# %% [markdown]
# Runs a parcel simulation based on Pyrcel documentation setup, and demonstrates export to VTK and visualisation using Paraview
#
# (requires `pvpython` command in PATH)

# %%
import os, sys
os.environ['NUMBA_THREADING_LAYER'] = 'workqueue'  # PySDM & PyMPDATA don't work with TBB; OpenMP has extra dependencies on macOS
if 'google.colab' in sys.modules:
    # !pip --quiet install open-atmos-jupyter-utils
    from open_atmos_jupyter_utils import pip_install_on_colab
    pip_install_on_colab('PySDM-examples', 'PySDM')

# %%
import numpy as np
import subprocess
import platform
import pathlib
from PySDM import Formulae
from PySDM.physics import si
from PySDM.initialisation.spectra import Lognormal
from PySDM.products import (
    ParcelDisplacement,
    AmbientTemperature,
    AmbientDryAirDensity,
    AmbientRelativeHumidity,
    ParticleSizeSpectrumPerVolume,
    ParticleVolumeVersusRadiusLogarithmSpectrum,
)
from PySDM.exporters import VTKExporterParcel

from PySDM_examples.Pyrcel import Settings, Simulation
import PySDM_examples

# %%
settings = Settings(
    dz=10 * si.m,
    n_sd_per_mode=(25, 25),
    aerosol_modes_by_kappa={
        0.54: Lognormal(
            norm_factor=850 / si.cm**3,
            median=15 * si.nm,
            s_geom=1.6,
        ),
        1.2: Lognormal(
            norm_factor=10 / si.cm**3,
            median=850 * si.nm,
            s_geom=1.2,
        ),
    },
    vertical_velocity=1.0 * si.m / si.s,
    initial_pressure=775 * si.mbar,
    initial_temperature=274 * si.K,
    initial_relative_humidity=0.90,
    displacement=1000 * si.m,
    formulae=Formulae(constants={"MAC": 0.3}),
)

dry_radius_bin_edges = np.logspace(
    np.log10(1e-3 * si.um), np.log10(5e0 * si.um), 33, endpoint=False
)

simulation = Simulation(
    settings,
    products=(
        ParcelDisplacement(name="z"),
        AmbientRelativeHumidity(name="S_max_percent", unit="%", var="RH"),
        AmbientTemperature(name="T"),
        ParticleSizeSpectrumPerVolume(
            name="dry:dN/dR", radius_bins_edges=dry_radius_bin_edges, dry=True
        ),
        ParticleVolumeVersusRadiusLogarithmSpectrum(
            name="dry:dV/dlnR", radius_bins_edges=dry_radius_bin_edges, dry=True
        ),
        AmbientDryAirDensity(),
    ),
    mass_of_dry_air = 66666 * si.kg,
)

# %%
output = simulation.run()

# %%
e = VTKExporterParcel(n_sd=simulation.particulator.n_sd, output=output, mass_of_dry_air=simulation.particulator.environment.mass_of_dry_air)
for step in settings.output_steps:
    e.export_products(step, simulation)
    e.export_attributes(step, simulation)
e.write_pvd()

# %%
product = pathlib.Path("./output/sd_products.pvd").absolute()
attributes = pathlib.Path("./output/sd_attributes.pvd").absolute()

paraview_script = pathlib.Path(PySDM_examples.__file__).parent / 'Strzabala_2025_BEng' / "paraview_parcel_model.py"

args = [
    "pvpython",
    "--force-offscreen-rendering",
    str(paraview_script),
    "--sd-products-pvd",
    str(product),
    "--sd-attributes-pvd",
    str(attributes),
    "--output-animation-path",
    str(pathlib.Path("./output/parcel_animation.ogv").absolute()),
    "--output-screenshot-path",
    str(pathlib.Path("./output/last_frame.pdf").absolute()),
]
result = subprocess.run(
    args,
    check=platform.system() != "Windows",
    capture_output=True,
    text=True,
)

# %% [markdown]
# ### PyVista

# %%
import pyvista as pv
import vtk

pv.set_jupyter_backend('static')
readers = {
    'prod': pv.get_reader("./output/sd_products.pvd"),
    'attr': pv.get_reader("./output/sd_attributes.pvd")
}
# !ls -l
# Out:
# total 4532
# -rw-rw-r-- 1 alicja alicja     240 Mar 18 14:35 __init__.py
# drwxrwxr-x 2 alicja alicja   16384 Apr 13 10:20 output
# -rw-rw-r-- 1 alicja alicja  412275 Apr 13 15:49 paraview.ipynb
# -rw-rw-r-- 1 alicja alicja    7598 Mar 18 14:35 paraview_parcel_model.py
# -rw------- 1 alicja alicja       0 Apr 13 15:14 tmp1wpmhcee.gif
# -rw------- 1 alicja alicja       0 Apr 13 15:26 tmp6bmq_fo3.gif
# -rw------- 1 alicja alicja  114110 Apr 13 12:39 tmpafocl0uu.gif
# -rw------- 1 alicja alicja 2780100 Apr 13 15:54 tmpd3mgxlws.gif
# -rw------- 1 alicja alicja 1071709 Apr 13 15:42 tmpf4loqbnx.gif
# -rw------- 1 alicja alicja  114110 Apr 13 12:38 tmpi23mjyn4.gif
# -rw------- 1 alicja alicja       0 Apr 13 15:40 tmpldkwvnew.gif
# -rw------- 1 alicja alicja       0 Apr 13 12:46 tmpm8vhmpsv.gif
# -rw------- 1 alicja alicja       0 Apr 13 12:54 tmpm90rsiws.gif
# -rw------- 1 alicja alicja       0 Apr 13 15:40 tmp_pp6t60u.gif
# -rw------- 1 alicja alicja       0 Apr 13 12:36 tmpqtq09zq_.gif
# -rw------- 1 alicja alicja  114110 Apr 13 12:45 tmptk71oclf.gif
# -rw------- 1 alicja alicja       0 Apr 13 14:55 tmpwdmdwsax.gif
# -rw------- 1 alicja alicja       0 Apr 13 15:39 tmpyr378mu2.gif

# %%
vmin, vmax = readers['prod'].min(), readers.max()

from open_atmos_jupyter_utils import TemporaryFile
gif_file = TemporaryFile(suffix=".gif")

pl = pv.Plotter(notebook=False, off_screen=True)
pl.open_gif(gif_file.basename, subrectangles=True)
for i in range(readers['prod'].number_time_points):
    for reader in readers.values():
        reader.set_active_time_point(i)

    pl.add_mesh(
        readers['prod'].read()[0],
        scalars='RH',
        opacity = 0.15
        # show_edges=False,
        # cmap=colors.ListedColormap(["white", "#993399", "#00CCFF", "#66CC00","#FC8727","#FFFF00"]),
        # clim=[vmin, vmax],
    )
    pl.add_mesh(
        readers['attr'].read()[0]
    )
    pl.render()
    pl.write_frame()

pl.close()
# Out:
# /home/alicja/Desktop/OpenAtmos/.venv/lib/python3.12/site-packages/pyvista/plotting/mapper.py:686: RuntimeWarning: All-NaN axis encountered
#   clim = [np.nanmin(scalars), np.nanmax(scalars)]

# %%
#time_values = reader.time_values

mesh = pv.read(filename)
grid = pv.ImageData()

pl = pv.Plotter(notebook=False, off_screen=True)
pl.add_mesh(mesh)

#reader.set_active_time_value(time_values[0])
#mesh = reader.read()[0]

from open_atmos_jupyter_utils import TemporaryFile
gif_file = TemporaryFile(suffix=".gif")

pl.open_gif(gif_file.basename, subrectangles=True)
title_actor = None

for step in reader.time_values:
    if title_actor is not None:
        pl.remove_actor(title_actor)

    title_actor = pl.add_text(
        "step:" + str(step),
        position='upper_edge',
        font_size=14,
        color='black'
    )
    #reader.set_active_time_value(step)
    #new_mesh = reader.read()[0]
    mesh.plot(step)
    pl.render()
    pl.write_frame()

pl.close()
# Out:
# /home/alicja/Desktop/OpenAtmos/.venv/lib/python3.12/site-packages/pyvista/core/dataset.py:967: RuntimeWarning: All-NaN axis encountered
#   return np.nanmin(arr), np.nanmax(arr)
# ERROR:root:Bad table range: [inf, -inf]
# 2026-04-13 15:26:31.010 ( 751.252s) [    7FE700BA21C0]     vtkLookupTable.cxx:163    ERR| vtkLookupTable (0x52b9e6e0): Bad table range: [inf, -inf]
# <PIL.Image.Image image mode=RGB size=1024x768>
# /home/alicja/Desktop/OpenAtmos/.venv/lib/python3.12/site-packages/pyvista/core/dataset.py:967: RuntimeWarning: All-NaN axis encountered
#   return np.nanmin(arr), np.nanmax(arr)
# /tmp/ipykernel_30275/1489819814.py:31: PyVistaDeprecationWarning:
# /tmp/ipykernel_30275/1489819814.py:31: Argument 'off_screen' must be passed as a keyword argument to function 'plot'.
# From version 0.50, passing this as a positional argument will result in a TypeError.
#   mesh.plot(step)
# /home/alicja/Desktop/OpenAtmos/.venv/lib/python3.12/site-packages/pyvista/core/dataset.py:967: RuntimeWarning: All-NaN axis encountered
#   return np.nanmin(arr), np.nanmax(arr)
# 2026-04-13 15:26:31.456 ( 751.698s) [    7FE700BA21C0]     vtkLookupTable.cxx:163    ERR| vtkLookupTable (0x53d72040): Bad table range: [inf, -inf]
# ERROR:root:Bad table range: [inf, -inf]
# <PIL.Image.Image image mode=RGB size=1024x768>
# 2026-04-13 15:26:31.672 ( 751.914s) [    7FE700BA21C0]     vtkLookupTable.cxx:163    ERR| vtkLookupTable (0x53d72210): Bad table range: [inf, -inf]
# ERROR:root:Bad table range: [inf, -inf]
# /tmp/ipykernel_30275/1489819814.py:31: PyVistaDeprecationWarning:
# /tmp/ipykernel_30275/1489819814.py:31: Argument 'off_screen' must be passed as a keyword argument to function 'plot'.
# From version 0.50, passing this as a positional argument will result in a TypeError.
#   mesh.plot(step)
# /home/alicja/Desktop/OpenAtmos/.venv/lib/python3.12/site-packages/pyvista/core/dataset.py:967: RuntimeWarning: All-NaN axis encountered
#   return np.nanmin(arr), np.nanmax(arr)
# 2026-04-13 15:26:32.114 ( 752.356s) [    7FE700BA21C0]     vtkLookupTable.cxx:163    ERR| vtkLookupTable (0x4f8a1180): Bad table range: [inf, -inf]
# ERROR:root:Bad table range: [inf, -inf]
# <PIL.Image.Image image mode=RGB size=1024x768>
# /tmp/ipykernel_30275/1489819814.py:31: PyVistaDeprecationWarning:
# /tmp/ipykernel_30275/1489819814.py:31: Argument 'off_screen' must be passed as a keyword argument to function 'plot'.
# From version 0.50, passing this as a positional argument will result in a TypeError.
#   mesh.plot(step)
# /home/alicja/Desktop/OpenAtmos/.venv/lib/python3.12/site-packages/pyvista/core/dataset.py:967: RuntimeWarning: All-NaN axis encountered
#   return np.nanmin(arr), np.nanmax(arr)
# ERROR:root:Bad table range: [inf, -inf]
# 2026-04-13 15:26:32.801 ( 753.043s) [    7FE700BA21C0]     vtkLookupTable.cxx:163    ERR| vtkLookupTable (0x54d63450): Bad table range: [inf, -inf]
# <PIL.Image.Image image mode=RGB size=1024x768>
# /tmp/ipykernel_30275/1489819814.py:31: PyVistaDeprecationWarning:
# /tmp/ipykernel_30275/1489819814.py:31: Argument 'off_screen' must be passed as a keyword argument to function 'plot'.
# From version 0.50, passing this as a positional argument will result in a TypeError.
#   mesh.plot(step)
# /home/alicja/Desktop/OpenAtmos/.venv/lib/python3.12/site-packages/pyvista/core/dataset.py:967: RuntimeWarning: All-NaN axis encountered
#   return np.nanmin(arr), np.nanmax(arr)
# ERROR:root:Bad table range: [inf, -inf]
# 2026-04-13 15:26:33.485 ( 753.727s) [    7FE700BA21C0]     vtkLookupTable.cxx:163    ERR| vtkLookupTable (0x55a45e40): Bad table range: [inf, -inf]
# <PIL.Image.Image image mode=RGB size=1024x768>
# /tmp/ipykernel_30275/1489819814.py:31: PyVistaDeprecationWarning:
# /tmp/ipykernel_30275/1489819814.py:31: Argument 'off_screen' must be passed as a keyword argument to function 'plot'.
# From version 0.50, passing this as a positional argument will result in a TypeError.
#   mesh.plot(step)
# /home/alicja/Desktop/OpenAtmos/.venv/lib/python3.12/site-packages/pyvista/core/dataset.py:967: RuntimeWarning: All-NaN axis encountered
#   return np.nanmin(arr), np.nanmax(arr)
# ERROR:root:Bad table range: [inf, -inf]
# 2026-04-13 15:26:34.039 ( 754.281s) [    7FE700BA21C0]     vtkLookupTable.cxx:163    ERR| vtkLookupTable (0x55f67890): Bad table range: [inf, -inf]
# <PIL.Image.Image image mode=RGB size=1024x768>
# /tmp/ipykernel_30275/1489819814.py:31: PyVistaDeprecationWarning:
# /tmp/ipykernel_30275/1489819814.py:31: Argument 'off_screen' must be passed as a keyword argument to function 'plot'.
# From version 0.50, passing this as a positional argument will result in a TypeError.
#   mesh.plot(step)
# /home/alicja/Desktop/OpenAtmos/.venv/lib/python3.12/site-packages/pyvista/core/dataset.py:967: RuntimeWarning: All-NaN axis encountered
#   return np.nanmin(arr), np.nanmax(arr)

# %%
for name in reader.keys():
    block = reader[name]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 for name in reader.keys():
#       2     block = reader[name]
#
# AttributeError: 'PVDReader' object has no attribute 'keys'
