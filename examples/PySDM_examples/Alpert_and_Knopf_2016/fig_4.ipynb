# %% [markdown]
# [![preview notebook](https://img.shields.io/static/v1?label=render%20on&logo=github&color=87ce3e&message=GitHub)](https://github.com/open-atmos/PySDM/blob/main/examples/PySDM_examples/Alpert_and_Knopf_2016/fig_4.ipynb)
# [![launch on mybinder.org](https://mybinder.org/badge_logo.svg)](https://mybinder.org/v2/gh/open-atmos/PySDM.git/main?urlpath=lab/tree/examples/PySDM_examples/Alpert_and_Knopf_2016/fig_4.ipynb)
# [![launch on Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/open-atmos/PySDM/blob/main/examples/PySDM_examples/Alpert_and_Knopf_2016/fig_4.ipynb)

# %% [markdown]
# #### based on Fig. 4 from Alpert and Knopf 2016 (Atmos. Chem. Phys. 16) "_Analysis of isothermal and cooling-rate-dependent immersion freezing by a unifying stochastic ice nucleation model_"
# https://doi.org/10.5194/acp-16-2083-2016

# %%
import os, sys
os.environ['NUMBA_THREADING_LAYER'] = 'workqueue'  # PySDM & PyMPDATA don't work with TBB; OpenMP has extra dependencies on macOS
if 'google.colab' in sys.modules:
    # !pip --quiet install open-atmos-jupyter-utils
    from open_atmos_jupyter_utils import pip_install_on_colab
    pip_install_on_colab('PySDM-examples', 'PySDM')

# %%
from open_atmos_jupyter_utils import show_plot
from PySDM_examples.Alpert_and_Knopf_2016 import Simulation, Table2
from matplotlib import pylab
from PySDM.physics import si

# %%
cases = Table2()

# %%
sim = Simulation(cases=cases, time_step=5*si.s, heterogeneous_ice_nucleation_rate='ABIFM',
                 temperature_range=(228*si.K, 258*si.K))

# %%
sim.run(('Cr1', 'Cr2'))

# %%
sim.plot_j_het(variant='apparent', ylim=(1e-4, 1e10), abifm_params_case='Cr1')
pylab.title("a")
show_plot('fig_4a.pdf')

# %%
sim.plot_j_het(variant='actual', ylim=(1e-4, 1e10), abifm_params_case='Cr1')
pylab.title("b")
show_plot('fig_4b.pdf')

# %%
sim.plot(ylim=(0, 1))
pylab.title("c, d")
show_plot('fig_4cd.pdf')
