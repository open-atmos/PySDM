# %% [markdown]
# [![preview notebook](https://img.shields.io/static/v1?label=render%20on&logo=github&color=87ce3e&message=GitHub)](https://github.com/open-atmos/PySDM/blob/main/examples/PySDM_examples/Alpert_and_Knopf_2016/fig_2.ipynb)
# [![launch on mybinder.org](https://mybinder.org/badge_logo.svg)](https://mybinder.org/v2/gh/open-atmos/PySDM.git/main?urlpath=lab/tree/examples/PySDM_examples/Alpert_and_Knopf_2016/fig_2.ipynb)
# [![launch on Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/open-atmos/PySDM/blob/main/examples/PySDM_examples/Alpert_and_Knopf_2016/fig_2.ipynb)

# %% [markdown]
# #### based on Fig. 2 from Alpert and Knopf 2016 (Atmos. Chem. Phys. 16) "_Analysis of isothermal and cooling-rate-dependent immersion freezing by a unifying stochastic ice nucleation model_"
# https://doi.org/10.5194/acp-16-2083-2016

# %%
import os, sys
os.environ['NUMBA_THREADING_LAYER'] = 'workqueue'  # PySDM & PyMPDATA don't work with TBB; OpenMP has extra dependencies on macOS
if 'google.colab' in sys.modules:
    # !pip --quiet install open-atmos-jupyter-utils
    from open_atmos_jupyter_utils import pip_install_on_colab
    pip_install_on_colab('PySDM-examples', 'PySDM')

# %%
from open_atmos_jupyter_utils import show_plot
from PySDM_examples.Alpert_and_Knopf_2016 import Simulation, Table1
from PySDM.physics import si

# %%
cases = Table1()

# %% [markdown]
# ### Fig 2 a

# %%
sim_2a = Simulation(cases=cases, time_step=10*si.s, total_time=14*si.min)
sim_2a.run(('IsoBR',))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 2
#       1 sim_2a = Simulation(cases=cases, time_step=10*si.s, total_time=14*si.min)
# ----> 2 sim_2a.run(('IsoBR',))
#
# File ~/PySDM/examples/PySDM_examples/Alpert_and_Knopf_2016/simulation.py:74, in Simulation.run(self, keys)
#      70 n_sd = int(n_sd)
#      71 initial_temp = (
#      72     self.temperature_range[1] if self.temperature_range else np.nan
#      73 )
# ---> 74 f_ufz, a_tot = simulation(
#      75     constants=constants,
#      76     seed=i,
#      77     n_sd=n_sd,
#      78     time_step=self.time_step,
#      79     volume=self.volume,
#      80     spectrum=case["ISA"],
#      81     droplet_volume=self.droplet_volume,
#      82     multiplicity=self.multiplicity,
#      83     total_time=total_time,
#      84     number_of_real_droplets=number_of_real_droplets,
#      85     cooling_rate=self.cases[key]["cooling_rate"],
#      86     heterogeneous_ice_nucleation_rate=self.heterogeneous_ice_nucleation_rate,
#      87     initial_temperature=initial_temp,
#      88 )
#      89 self.output[key].append({"f_ufz": f_ufz, "A_tot": a_tot})
#
# File ~/PySDM/examples/PySDM_examples/Alpert_and_Knopf_2016/simulation.py:270, in simulation(constants, seed, n_sd, time_step, volume, spectrum, droplet_volume, multiplicity, total_time, number_of_real_droplets, cooling_rate, heterogeneous_ice_nucleation_rate, initial_temperature)
#     268     unfrozen_fraction = 1 - ice_number / number_of_real_droplets
#     269     f_ufz.append(unfrozen_fraction)
# --> 270     a_tot.append(particulator.products["A_tot"].get()[cell_id])
#     271 return f_ufz, a_tot
#
# File ~/PySDM/PySDM/products/impl/product.py:99, in Product.get(self, **kwargs)
#      98 def get(self, **kwargs):
# ---> 99     result = self._impl(**kwargs)
#     100     result /= self.unit_magnitude_in_base_units
#     101     return result
#
# File ~/PySDM/PySDM/products/freezing/total_unfrozen_immersed_surface_area.py:21, in TotalUnfrozenImmersedSurfaceArea._impl(self, **kwargs)
#      15 def _impl(self, **kwargs):
#      16     params = {
#      17         "attr": "immersed surface area",
#      18         "filter_attr": "volume",
#      19         "filter_range": (0, np.inf),
#      20     }
# ---> 21     self._download_moment_to_buffer(**params, rank=1)
#      22     result = np.copy(self.buffer)
#      23     self._download_moment_to_buffer(**params, rank=0)
#
# File ~/PySDM/PySDM/products/impl/moment_product.py:36, in MomentProduct._download_moment_to_buffer(self, attr, rank, filter_attr, filter_range, weighting_attribute, weighting_rank, skip_division_by_m0)
#      25 def _download_moment_to_buffer(
#      26     self,
#      27     *,
#    (...)     34     skip_division_by_m0=False,
#      35 ):
# ---> 36     self.particulator.moments(
#      37         moment_0=self.moment_0,
#      38         moments=self.moments,
#      39         specs={attr: (rank,)},
#      40         attr_name=filter_attr,
#      41         attr_range=filter_range,
#      42         weighting_attribute=weighting_attribute,
#      43         weighting_rank=weighting_rank,
#      44         skip_division_by_m0=skip_division_by_m0,
#      45     )
#      46     if rank == 0:  # TODO #217
#      47         self._download_to_buffer(self.moment_0)
#
# File ~/PySDM/PySDM/particulator.py:399, in Particulator.moments(self, moment_0, moments, specs, attr_name, attr_range, weighting_attribute, weighting_rank, skip_division_by_m0)
#     395     attr_data = attr_data[0]
#     397 ranks = self.backend.Storage.from_ndarray(np.array(ranks, dtype=float))
# --> 399 self.backend.moments(
#     400     moment_0=moment_0,
#     401     moments=moments,
#     402     multiplicity=self.attributes["multiplicity"],
#     403     attr_data=attr_data,
#     404     cell_id=self.attributes["cell id"],
#     405     idx=self.attributes._ParticleAttributes__idx,
#     406     length=self.attributes.super_droplet_count,
#     407     ranks=ranks,
#     408     min_x=attr_range[0],
#     409     max_x=attr_range[1],
#     410     x_attr=self.attributes[attr_name],
#     411     weighting_attribute=self.attributes[weighting_attribute],
#     412     weighting_rank=weighting_rank,
#     413     skip_division_by_m0=skip_division_by_m0,
#     414 )
#
# File ~/PySDM/PySDM/backends/impl_numba/methods/moments_methods.py:84, in MomentsMethods.moments(self, moment_0, moments, multiplicity, attr_data, cell_id, idx, length, ranks, min_x, max_x, x_attr, weighting_attribute, weighting_rank, skip_division_by_m0)
#      66 def moments(
#      67     self,
#      68     *,
#    (...)     82     skip_division_by_m0,
#      83 ):
# ---> 84     return self._moments_body(
#      85         moment_0=moment_0.data,
#      86         moments=moments.data,
#      87         multiplicity=multiplicity.data,
#      88         attr_data=attr_data.data,
#      89         cell_id=cell_id.data,
#      90         idx=idx.data,
#      91         length=length,
#      92         ranks=ranks.data,
#      93         min_x=min_x,
#      94         max_x=max_x,
#      95         x_attr=x_attr.data,
#      96         weighting_attribute=weighting_attribute.data,
#      97         weighting_rank=weighting_rank,
#      98         skip_division_by_m0=skip_division_by_m0,
#      99     )
#
# File ~/.venvs/pysdm/lib64/python3.13/site-packages/numba/core/dispatcher.py:376, in _DispatcherBase._compile_for_args(self, *args, **kws)
#     374 return_val = None
#     375 try:
# --> 376     return_val = self.compile(tuple(argtypes))
#     377 except errors.ForceLiteralArg as e:
#     378     # Received request for compiler re-entry with the list of arguments
#     379     # indicated by e.requested_args.
#     380     # First, check if any of these args are already Literal-ized
#     381     already_lit_pos = [i for i in e.requested_args
#     382                        if isinstance(args[i], types.Literal)]
#
# File ~/.venvs/pysdm/lib64/python3.13/site-packages/numba/core/dispatcher.py:908, in Dispatcher.compile(self, sig)
#     906 with ev.trigger_event("numba:compile", data=ev_details):
#     907     try:
# --> 908         cres = self._compiler.compile(args, return_type)
#     909     except errors.ForceLiteralArg as e:
#     910         def folded(args, kws):
#
# File ~/.venvs/pysdm/lib64/python3.13/site-packages/numba/core/dispatcher.py:80, in _FunctionCompiler.compile(self, args, return_type)
#      79 def compile(self, args, return_type):
# ---> 80     status, retval = self._compile_cached(args, return_type)
#      81     if status:
#      82         return retval
#
# File ~/.venvs/pysdm/lib64/python3.13/site-packages/numba/core/dispatcher.py:94, in _FunctionCompiler._compile_cached(self, args, return_type)
#      91     pass
#      93 try:
# ---> 94     retval = self._compile_core(args, return_type)
#      95 except errors.TypingError as e:
#      96     self._failed_cache[key] = e
#
# File ~/.venvs/pysdm/lib64/python3.13/site-packages/numba/core/dispatcher.py:107, in _FunctionCompiler._compile_core(self, args, return_type)
#     104 flags = self._customize_flags(flags)
#     106 impl = self._get_implementation(args, {})
# --> 107 cres = compiler.compile_extra(self.targetdescr.typing_context,
#     108                               self.targetdescr.target_context,
#     109                               impl,
#     110                               args=args, return_type=return_type,
#     111                               flags=flags, locals=self.locals,
#     112                               pipeline_class=self.pipeline_class)
#     113 # Check typing error if object mode is used
#     114 if cres.typing_error is not None and not flags.enable_pyobject:
#
# File ~/.venvs/pysdm/lib64/python3.13/site-packages/numba/core/compiler.py:739, in compile_extra(typingctx, targetctx, func, args, return_type, flags, locals, library, pipeline_class)
#     715 """Compiler entry point
#     716
#     717 Parameter
#    (...)    735     compiler pipeline
#     736 """
#     737 pipeline = pipeline_class(typingctx, targetctx, library,
#     738                           args, return_type, flags, locals)
# --> 739 return pipeline.compile_extra(func)
#
# File ~/.venvs/pysdm/lib64/python3.13/site-packages/numba/core/compiler.py:439, in CompilerBase.compile_extra(self, func)
#     437 self.state.lifted = ()
#     438 self.state.lifted_from = None
# --> 439 return self._compile_bytecode()
#
# File ~/.venvs/pysdm/lib64/python3.13/site-packages/numba/core/compiler.py:505, in CompilerBase._compile_bytecode(self)
#     501 """
#     502 Populate and run pipeline for bytecode input
#     503 """
#     504 assert self.state.func_ir is None
# --> 505 return self._compile_core()
#
# File ~/.venvs/pysdm/lib64/python3.13/site-packages/numba/core/compiler.py:473, in CompilerBase._compile_core(self)
#     471 res = None
#     472 try:
# --> 473     pm.run(self.state)
#     474     if self.state.cr is not None:
#     475         break
#
# File ~/.venvs/pysdm/lib64/python3.13/site-packages/numba/core/compiler_machinery.py:356, in PassManager.run(self, state)
#     354 pass_inst = _pass_registry.get(pss).pass_inst
#     355 if isinstance(pass_inst, CompilerPass):
# --> 356     self._runPass(idx, pass_inst, state)
#     357 else:
#     358     raise BaseException("Legacy pass in use")
#
# File ~/.venvs/pysdm/lib64/python3.13/site-packages/numba/core/compiler_lock.py:35, in _CompilerLock.__call__.<locals>._acquire_compile_lock(*args, **kwargs)
#      32 @functools.wraps(func)
#      33 def _acquire_compile_lock(*args, **kwargs):
#      34     with self:
# ---> 35         return func(*args, **kwargs)
#
# File ~/.venvs/pysdm/lib64/python3.13/site-packages/numba/core/compiler_machinery.py:311, in PassManager._runPass(self, index, pss, internal_state)
#     309     mutated |= check(pss.run_initialization, internal_state)
#     310 with SimpleTimer() as pass_time:
# --> 311     mutated |= check(pss.run_pass, internal_state)
#     312 with SimpleTimer() as finalize_time:
#     313     mutated |= check(pss.run_finalizer, internal_state)
#
# File ~/.venvs/pysdm/lib64/python3.13/site-packages/numba/core/compiler_machinery.py:272, in PassManager._runPass.<locals>.check(func, compiler_state)
#     271 def check(func, compiler_state):
# --> 272     mangled = func(compiler_state)
#     273     if mangled not in (True, False):
#     274         msg = ("CompilerPass implementations should return True/False. "
#     275                "CompilerPass with name '%s' did not.")
#
# File ~/.venvs/pysdm/lib64/python3.13/site-packages/numba/core/typed_passes.py:472, in BaseNativeLowering.run_pass(self, state)
#     469 with targetctx.push_code_library(library):
#     470     lower = self.lowering_class(targetctx, library, fndesc, interp,
#     471                                 metadata=metadata)
# --> 472     lower.lower()
#     473     if not flags.no_cpython_wrapper:
#     474         lower.create_cpython_wrapper(flags.release_gil)
#
# File ~/.venvs/pysdm/lib64/python3.13/site-packages/numba/core/lowering.py:193, in BaseLower.lower(self)
#     191 if self.generator_info is None:
#     192     self.genlower = None
# --> 193     self.lower_normal_function(self.fndesc)
#     194 else:
#     195     self.genlower = self.GeneratorLower(self)
#
# File ~/.venvs/pysdm/lib64/python3.13/site-packages/numba/core/lowering.py:232, in BaseLower.lower_normal_function(self, fndesc)
#     230 # Init argument values
#     231 self.extract_function_arguments()
# --> 232 entry_block_tail = self.lower_function_body()
#     234 # Close tail of entry block, do not emit debug metadata else the
#     235 # unconditional jump gets associated with the metadata from the function
#     236 # body end.
#     237 with debuginfo.suspend_emission(self.builder):
#
# File ~/.venvs/pysdm/lib64/python3.13/site-packages/numba/core/lowering.py:262, in BaseLower.lower_function_body(self)
#     260     self.builder.position_at_end(bb)
#     261     self.debug_print(f"# lower block: {offset}")
# --> 262     self.lower_block(block)
#     263 self.post_lower()
#     264 return entry_block_tail
#
# File ~/.venvs/pysdm/lib64/python3.13/site-packages/numba/core/lowering.py:276, in BaseLower.lower_block(self, block)
#     273     defaulterrcls = partial(LoweringError, loc=self.loc)
#     274     with new_error_context('lowering "{inst}" at {loc}', inst=inst,
#     275                            loc=self.loc, errcls_=defaulterrcls):
# --> 276         self.lower_inst(inst)
#     277 self.post_block(block)
#
# File ~/.venvs/pysdm/lib64/python3.13/site-packages/numba/parfors/parfor_lowering.py:52, in ParforLower.lower_inst(self, inst)
#      50 def lower_inst(self, inst):
#      51     if isinstance(inst, parfor.Parfor):
# ---> 52         _lower_parfor_parallel(self, inst)
#      53     else:
#      54         super().lower_inst(inst)
#
# File ~/.venvs/pysdm/lib64/python3.13/site-packages/numba/parfors/parfor_lowering.py:68, in _lower_parfor_parallel(lowerer, parfor)
#      66 def _lower_parfor_parallel(lowerer, parfor):
#      67     if parfor.lowerer is None:
# ---> 68         return _lower_parfor_parallel_std(lowerer, parfor)
#      69     else:
#      70         return parfor.lowerer(lowerer, parfor)
#
# File ~/.venvs/pysdm/lib64/python3.13/site-packages/numba/parfors/parfor_lowering.py:382, in _lower_parfor_parallel_std(lowerer, parfor)
#     380     print("loop_nests = ", parfor.loop_nests)
#     381     print("loop_ranges = ", loop_ranges)
# --> 382 call_parallel_gufunc(
#     383     lowerer,
#     384     func,
#     385     gu_signature,
#     386     func_sig,
#     387     func_args,
#     388     func_arg_types,
#     389     loop_ranges,
#     390     parfor_redvars,
#     391     parfor_reddict,
#     392     redarrs,
#     393     parfor.init_block,
#     394     index_var_typ,
#     395     parfor.races,
#     396     exp_name_to_tuple_var)
#     398 if nredvars > 0:
#     399     _parfor_lowering_finalize_reduction(
#     400         parfor, redarrs, lowerer, parfor_reddict, num_threads_var,
#     401     )
#
# File ~/.venvs/pysdm/lib64/python3.13/site-packages/numba/parfors/parfor_lowering.py:1695, in call_parallel_gufunc(lowerer, cres, gu_signature, outer_sig, expr_args, expr_arg_types, loop_ranges, redvars, reddict, redarrdict, init_block, index_var_typ, races, exp_name_to_tuple_var)
#    1692 # These are necessary for build_gufunc_wrapper to find external symbols
#    1693 _launch_threads()
# -> 1695 info = build_gufunc_wrapper(llvm_func, cres, sin, sout,
#    1696                             cache=False, is_parfors=True)
#    1697 wrapper_name = info.name
#    1698 cres.library._ensure_finalized()
#
# File ~/.venvs/pysdm/lib64/python3.13/site-packages/numba/np/ufunc/parallel.py:273, in build_gufunc_wrapper(py_func, cres, sin, sout, cache, is_parfors)
#     270 sym_out = set(sym for term in sout for sym in term)
#     271 inner_ndim = len(sym_in | sym_out)
# --> 273 info = build_gufunc_kernel(
#     274     library, ctx, innerinfo, signature, inner_ndim,
#     275 )
#     276 return info
#
# File ~/.venvs/pysdm/lib64/python3.13/site-packages/numba/np/ufunc/parallel.py:152, in build_gufunc_kernel(library, ctx, info, sig, inner_ndim)
#     146 innerfunc_fnty = ir.FunctionType(
#     147     ir.VoidType(),
#     148     [byte_ptr_ptr_t, intp_ptr_t, intp_ptr_t, byte_ptr_t],
#     149 )
#     150 tmp_voidptr = cgutils.get_or_insert_function(mod, innerfunc_fnty,
#     151                                              info.name,)
# --> 152 wrapperlib.add_linking_library(info.library)
#     154 get_num_threads = cgutils.get_or_insert_function(
#     155     builder.module,
#     156     ir.FunctionType(ir.IntType(types.intp.bitwidth), []),
#     157     "get_num_threads")
#     159 num_threads = builder.call(get_num_threads, [])
#
# File ~/.venvs/pysdm/lib64/python3.13/site-packages/numba/core/codegen.py:729, in CPUCodeLibrary.add_linking_library(self, library)
#     728 def add_linking_library(self, library):
# --> 729     library._ensure_finalized()
#     730     self._linking_libraries.append(library)
#
# File ~/.venvs/pysdm/lib64/python3.13/site-packages/numba/core/codegen.py:569, in CodeLibrary._ensure_finalized(self)
#     567 def _ensure_finalized(self):
#     568     if not self._finalized:
# --> 569         self.finalize()
#
# File ~/.venvs/pysdm/lib64/python3.13/site-packages/numba/core/codegen.py:773, in CPUCodeLibrary.finalize(self)
#     767         self._final_module.link_in(
#     768             library._get_module_for_linking(), preserve=True,
#     769         )
#     771 # Optimize the module after all dependences are linked in above,
#     772 # to allow for inlining.
# --> 773 self._optimize_final_module()
#     775 self._final_module.verify()
#     776 self._finalize_final_module()
#
# File ~/.venvs/pysdm/lib64/python3.13/site-packages/numba/core/codegen.py:691, in CPUCodeLibrary._optimize_final_module(self)
#     688 full_name = "Module passes (full optimization)"
#     689 with self._recorded_timings.record(full_name, mpb_full):
#     690     # The full optimisation suite is then run on the refop pruned IR
# --> 691     mpm_full.run(self._final_module, mpb_full)
#
# File ~/.venvs/pysdm/lib64/python3.13/site-packages/llvmlite/binding/newpassmanagers.py:122, in NewPassManager.run(self, IR, pb)
#     120 def run(self,IR, pb):
#     121     if isinstance(self, ModulePassManager):
# --> 122         ffi.lib.LLVMPY_RunNewModulePassManager(self, IR, pb)
#     123     else:
#     124         ffi.lib.LLVMPY_RunNewFunctionPassManager(self, IR, pb)
#
# File ~/.venvs/pysdm/lib64/python3.13/site-packages/llvmlite/binding/ffi.py:212, in _lib_fn_wrapper.__call__(self, *args, **kwargs)
#     210 def __call__(self, *args, **kwargs):
#     211     with self._lock:
# --> 212         return self._cfn(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
sim_2a.plot(ylim=(.5, 1))
show_plot('fig_2a.pdf')

# %% [markdown]
# ### Fig 2 b

# %%
sim_2b = Simulation(cases=cases, time_step=10*si.s, total_time=18*si.min)
sim_2b.run(('IsoHE1',))

# %%
sim_2b.plot(ylim=(1e-2, 1))
show_plot('fig_2b.pdf')

# %% [markdown]
# ### Fig 2 c

# %%
sim_2c = Simulation(cases=cases, time_step=100*si.s, total_time=150*si.min)
sim_2c.run(('IsoHE2',))

# %%
sim_2c.plot(ylim=(1e-2, 1))
show_plot('fig_2c.pdf')
