# %% [markdown]
# [![preview notebook](https://img.shields.io/static/v1?label=render%20on&logo=github&color=87ce3e&message=GitHub)](https://github.com/open-atmos/PySDM/blob/main/examples/PySDM_examples/Alpert_and_Knopf_2016/fig_2.ipynb)
# [![launch on mybinder.org](https://mybinder.org/badge_logo.svg)](https://mybinder.org/v2/gh/open-atmos/PySDM.git/main?urlpath=lab/tree/examples/PySDM_examples/Alpert_and_Knopf_2016/fig_2.ipynb)
# [![launch on Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/open-atmos/PySDM/blob/main/examples/PySDM_examples/Alpert_and_Knopf_2016/fig_2.ipynb)

# %% [markdown]
# #### based on Fig. 2 from Alpert and Knopf 2016 (Atmos. Chem. Phys. 16) "_Analysis of isothermal and cooling-rate-dependent immersion freezing by a unifying stochastic ice nucleation model_"
# https://doi.org/10.5194/acp-16-2083-2016

# %%
import os, sys
os.environ['NUMBA_THREADING_LAYER'] = 'workqueue'  # PySDM & PyMPDATA don't work with TBB; OpenMP has extra dependencies on macOS
if 'google.colab' in sys.modules:
    # !pip --quiet install open-atmos-jupyter-utils
    from open_atmos_jupyter_utils import pip_install_on_colab
    pip_install_on_colab('PySDM-examples', 'PySDM')

# %%
from open_atmos_jupyter_utils import show_plot
from PySDM_examples.Alpert_and_Knopf_2016 import Simulation, Table1
from PySDM.physics import si

# %%
cases = Table1()

# %% [markdown]
# ### Fig 2 a

# %%
sim_2a = Simulation(cases=cases, time_step=10*si.s, total_time=14*si.min)
sim_2a.run(('IsoBR',))

# %%
sim_2a.plot(ylim=(.5, 1))
show_plot('fig_2a.pdf')
# Out:
# HBox(children=(HTML(value="<a href='./fig_2a.pdf' target='_blank'>./fig_2a.pdf</a><br>"), HTML(value="<a href=…

# %% [markdown]
# ### Fig 2 b

# %%
sim_2b = Simulation(cases=cases, time_step=10*si.s, total_time=18*si.min)
sim_2b.run(('IsoHE1',))

# %%
sim_2b.plot(ylim=(1e-2, 1))
show_plot('fig_2b.pdf')
# Out:
# HBox(children=(HTML(value="<a href='./fig_2b.pdf' target='_blank'>./fig_2b.pdf</a><br>"), HTML(value="<a href=…

# %% [markdown]
# ### Fig 2 c

# %%
sim_2c = Simulation(cases=cases, time_step=100*si.s, total_time=150*si.min)
sim_2c.run(('IsoHE2',))

# %%
sim_2c.plot(ylim=(1e-2, 1))
show_plot('fig_2c.pdf')
# Out:
# HBox(children=(HTML(value="<a href='./fig_2c.pdf' target='_blank'>./fig_2c.pdf</a><br>"), HTML(value="<a href=…
