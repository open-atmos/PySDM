# %%
from PySDM_examples.Jensen_and_Nugent_2016 import Settings, Simulation
from open_atmos_jupyter_utils import show_plot
from PySDM_examples.Jensen_and_Nugent_2016.plotting import figure

settings = Settings(aerosol="modified polluted", cloud_type="Sc")
simulation = Simulation(settings)

# %%
output = simulation.run()
# Out:
# ---------------------------------------------------------------------------
# TypingError                               Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 output = simulation.run()
#
# File ~/PycharmProjects/PySDM/examples/PySDM_examples/Jensen_and_Nugent_2016/simulation.py:88, in Simulation.run(self, n_steps, steps_per_output_interval)
#      85 def run(
#      86     self, *, n_steps: int = 2250, steps_per_output_interval: int = 10
#      87 ):  # TODO: essentially copied from G & P 2023
# ---> 88     output_products = super()._run(n_steps, steps_per_output_interval)
#      89     return {"products": output_products, "attributes": self.output_attributes}
#
# File ~/PycharmProjects/PySDM/examples/PySDM_examples/utils/basic_simulation.py:19, in BasicSimulation._run(self, nt, steps_per_output_interval)
#      17 self._save(output)
#      18 for _ in range(0, nt + 1, steps_per_output_interval):
# ---> 19     self.particulator.run(steps=steps_per_output_interval)
#      20     self._save(output)
#      21 return output
#
# File ~/PycharmProjects/PySDM/PySDM/particulator.py:49, in Particulator.run(self, steps)
#      47 for key, dynamic in self.dynamics.items():
#      48     with self.timers[key]:
# ---> 49         dynamic()
#      50 self.n_steps += 1
#      51 self._notify_observers()
#
# File ~/PycharmProjects/PySDM/PySDM/dynamics/condensation.py:101, in Condensation.__call__(self)
#      98 else:
#      99     raise NotImplementedError()
# --> 101 self.particulator.condensation(
#     102     rtol_x=self.rtol_x,
#     103     rtol_thd=self.rtol_thd,
#     104     counters=self.counters,
#     105     RH_max=self.rh_max,
#     106     success=self.success,
#     107     cell_order=self.cell_order,
#     108 )
#     109 if not self.success.all():
#     110     raise RuntimeError("Condensation failed")
#
# File ~/PycharmProjects/PySDM/PySDM/particulator.py:118, in Particulator.condensation(self, rtol_x, rtol_thd, counters, RH_max, success, cell_order)
#     107 def condensation(self, *, rtol_x, rtol_thd, counters, RH_max, success, cell_order):
#     108     """Updates droplet volumes by simulating condensation driven by prior changes
#     109       in environment thermodynamic state, updates the environment state.
#     110     In the case of parcel environment, condensation is driven solely by changes in
#    (...)
#     116       `water_vapour_mixing_ratio` (and not `rhod`).
#     117     """
# --> 118     self.backend.condensation(
#     119         solver=self.condensation_solver,
#     120         n_cell=self.mesh.n_cell,
#     121         cell_start_arg=self.attributes.cell_start,
#     122         water_mass=self.attributes["water mass"],
#     123         multiplicity=self.attributes["multiplicity"],
#     124         vdry=self.attributes["dry volume"],
#     125         idx=self.attributes._ParticleAttributes__idx,
#     126         rhod=self.environment["rhod"],
#     127         thd=self.environment["thd"],
#     128         water_vapour_mixing_ratio=self.environment["water_vapour_mixing_ratio"],
#     129         dv=self.environment.dv,
#     130         prhod=self.environment.get_predicted("rhod"),
#     131         pthd=self.environment.get_predicted("thd"),
#     132         predicted_water_vapour_mixing_ratio=self.environment.get_predicted(
#     133             "water_vapour_mixing_ratio"
#     134         ),
#     135         kappa=self.attributes["kappa"],
#     136         f_org=self.attributes["dry volume organic fraction"],
#     137         rtol_x=rtol_x,
#     138         rtol_thd=rtol_thd,
#     139         v_cr=self.attributes["critical volume"],
#     140         timestep=self.dt,
#     141         counters=counters,
#     142         cell_order=cell_order,
#     143         RH_max=RH_max,
#     144         success=success,
#     145         cell_id=self.attributes["cell id"],
#     146     )
#     147     self.attributes.mark_updated("water mass")
#
# File ~/PycharmProjects/PySDM/PySDM/backends/impl_numba/methods/condensation_methods.py:49, in CondensationMethods.condensation(solver, n_cell, cell_start_arg, water_mass, v_cr, multiplicity, vdry, idx, rhod, thd, water_vapour_mixing_ratio, dv, prhod, pthd, predicted_water_vapour_mixing_ratio, kappa, f_org, rtol_x, rtol_thd, timestep, counters, cell_order, RH_max, success, cell_id)
#      19 @staticmethod
#      20 def condensation(
#      21     *,
#    (...)
#      46     cell_id,
#      47 ):
#      48     n_threads = min(numba.get_num_threads(), n_cell)
# ---> 49     CondensationMethods._condensation(
#      50         solver=solver,
#      51         n_threads=n_threads,
#      52         n_cell=n_cell,
#      53         cell_start_arg=cell_start_arg.data,
#      54         water_mass=water_mass.data,
#      55         v_cr=v_cr.data,
#      56         multiplicity=multiplicity.data,
#      57         vdry=vdry.data,
#      58         idx=idx.data,
#      59         rhod=rhod.data,
#      60         thd=thd.data,
#      61         water_vapour_mixing_ratio=water_vapour_mixing_ratio.data,
#      62         dv_mean=dv,
#      63         prhod=prhod.data,
#      64         pthd=pthd.data,
#      65         predicted_water_vapour_mixing_ratio=predicted_water_vapour_mixing_ratio.data,
#      66         kappa=kappa.data,
#      67         f_org=f_org.data,
#      68         rtol_x=rtol_x,
#      69         rtol_thd=rtol_thd,
#      70         timestep=timestep,
#      71         counter_n_substeps=counters["n_substeps"].data,
#      72         counter_n_activating=counters["n_activating"].data,
#      73         counter_n_deactivating=counters["n_deactivating"].data,
#      74         counter_n_ripening=counters["n_ripening"].data,
#      75         cell_order=cell_order,
#      76         RH_max=RH_max.data,
#      77         success=success.data,
#      78     )
#
# File ~/PycharmProjects/PySDM/venv/lib/python3.9/site-packages/numba/core/dispatcher.py:468, in _DispatcherBase._compile_for_args(self, *args, **kws)
#     464         msg = (f"{str(e).rstrip()} \n\nThis error may have been caused "
#     465                f"by the following argument(s):\n{args_str}\n")
#     466         e.patch_message(msg)
# --> 468     error_rewrite(e, 'typing')
#     469 except errors.UnsupportedError as e:
#     470     # Something unsupported is present in the user code, add help info
#     471     error_rewrite(e, 'unsupported_error')
#
# File ~/PycharmProjects/PySDM/venv/lib/python3.9/site-packages/numba/core/dispatcher.py:409, in _DispatcherBase._compile_for_args.<locals>.error_rewrite(e, issue_type)
#     407     raise e
#     408 else:
# --> 409     raise e.with_traceback(None)
#
# TypingError: Failed in nopython mode pipeline (step: nopython frontend)
# Failed in nopython mode pipeline (step: nopython frontend)
# Failed in nopython mode pipeline (step: nopython frontend)
# Failed in nopython mode pipeline (step: nopython frontend)
# Failed in nopython mode pipeline (step: nopython frontend)
# Internal error at <numba.core.typeinfer.CallConstraint object at 0x28c6c1b20>.
# Failed in nopython mode pipeline (step: inline inlinable functions)
# missing a required argument: 'T'
# During: resolving callee type: type(CPUDispatcher(<function CondensationMethods.make_calculate_ml_new.<locals>.calculate_ml_new at 0x286475d30>))
# During: typing of call at /Users/sanketbhiogade/PycharmProjects/PySDM/PySDM/backends/impl_numba/methods/condensation_methods.py (307)
#
# Enable logging at debug level for details.
#
# File "../../../PySDM/backends/impl_numba/methods/condensation_methods.py", line 307:
#         def step_impl(  # pylint: disable=too-many-arguments,too-many-locals
#             <source elided>
#                     n_ripening,
#                 ) = calculate_ml_new(
#                 ^
#
# During: resolving callee type: type(CPUDispatcher(<function CondensationMethods.make_step_impl.<locals>.step_impl at 0x286a38040>))
# During: typing of call at /Users/sanketbhiogade/PycharmProjects/PySDM/PySDM/backends/impl_numba/methods/condensation_methods.py (230)
#
# During: resolving callee type: type(CPUDispatcher(<function CondensationMethods.make_step_impl.<locals>.step_impl at 0x286a38040>))
# During: typing of call at /Users/sanketbhiogade/PycharmProjects/PySDM/PySDM/backends/impl_numba/methods/condensation_methods.py (230)
#
#
# File "../../../PySDM/backends/impl_numba/methods/condensation_methods.py", line 230:
#         def step_fake(args, dt, n_substeps):
#             <source elided>
#             dt /= n_substeps
#             _, thd_new, _, _, _, _, success = step_impl(*args, dt, 1, True)
#             ^
#
# During: resolving callee type: type(CPUDispatcher(<function CondensationMethods.make_step_fake.<locals>.step_fake at 0x286a38ca0>))
# During: typing of call at /Users/sanketbhiogade/PycharmProjects/PySDM/PySDM/backends/impl_numba/methods/condensation_methods.py (200)
#
# During: resolving callee type: type(CPUDispatcher(<function CondensationMethods.make_step_fake.<locals>.step_fake at 0x286a38ca0>))
# During: typing of call at /Users/sanketbhiogade/PycharmProjects/PySDM/PySDM/backends/impl_numba/methods/condensation_methods.py (207)
#
# During: resolving callee type: type(CPUDispatcher(<function CondensationMethods.make_step_fake.<locals>.step_fake at 0x286a38ca0>))
# During: typing of call at /Users/sanketbhiogade/PycharmProjects/PySDM/PySDM/backends/impl_numba/methods/condensation_methods.py (200)
#
#
# File "../../../PySDM/backends/impl_numba/methods/condensation_methods.py", line 200:
#         def adapt_substeps(args, n_substeps, thd, rtol_thd):
#             <source elided>
#                     )
#                 thd_new_long, success = step_fake(args, timestep, n_substeps)
#                 ^
#
# During: resolving callee type: type(CPUDispatcher(<function CondensationMethods.make_adapt_substeps.<locals>.adapt_substeps at 0x286a388b0>))
# During: typing of call at /Users/sanketbhiogade/PycharmProjects/PySDM/PySDM/backends/impl_numba/methods/condensation_methods.py (722)
#
# During: resolving callee type: type(CPUDispatcher(<function CondensationMethods.make_adapt_substeps.<locals>.adapt_substeps at 0x286a388b0>))
# During: typing of call at /Users/sanketbhiogade/PycharmProjects/PySDM/PySDM/backends/impl_numba/methods/condensation_methods.py (722)
#
#
# File "../../../PySDM/backends/impl_numba/methods/condensation_methods.py", line 722:
#         def solve(  # pylint: disable=too-many-arguments
#             <source elided>
#             if adaptive:
#                 n_substeps, success = adapt_substeps(args, n_substeps, thd, rtol_thd)
#                 ^
#
# During: resolving callee type: type(CPUDispatcher(<function CondensationMethods.make_condensation_solver_impl.<locals>.solve at 0x286a38700>))
# During: typing of call at /Users/sanketbhiogade/PycharmProjects/PySDM/PySDM/backends/impl_numba/methods/condensation_methods.py (141)
#
# During: resolving callee type: type(CPUDispatcher(<function CondensationMethods.make_condensation_solver_impl.<locals>.solve at 0x286a38700>))
# During: typing of call at /Users/sanketbhiogade/PycharmProjects/PySDM/PySDM/backends/impl_numba/methods/condensation_methods.py (141)
#
#
# File "../../../PySDM/backends/impl_numba/methods/condensation_methods.py", line 141:
#     def _condensation(
#         <source elided>
#                     RH_max_in_cell,
#                 ) = solver(
#                 ^

# %%
figure(
    output=output,
    settings=settings,
    simulation=simulation,
    drop_ids=(
        18,
        29,
        70,
        89,
        -1,
    ),
    xlim_r_um=(0, 15),
    xlim_S_percent=(-1, 1)
)
show_plot("Fig_3.pdf")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 figure(
# ----> 2     output=output,
#       3     settings=settings,
#       4     simulation=simulation,
#       5     drop_ids=(
#       6         18,
#       7         29,
#       8         70,
#       9         89,
#      10         -1,
#      11     ),
#      12     xlim_r_um=(0, 15),
#      13     xlim_S_percent=(-1, 1)
#      14 )
#      15 show_plot("Fig_3.pdf")
#
# NameError: name 'output' is not defined
