# %%
from PySDM_examples.Jensen_Nugent_2016 import Settings, Simulation
from open_atmos_jupyter_utils import show_plot
from PySDM_examples.Jensen_Nugent_2016.plotting import figure

settings = Settings(aerosol="modified polluted", cloud_type="Sc")
simulation = Simulation(settings, n_gccn=10)
const = settings.formulae.constants
# Out:
# /Users/sanketbhiogade/PycharmProjects/PySDM/PySDM/backends/impl_numba/conf.py:19: UserWarning: Disabling Numba threading due to ARM64 CPU (atomics do not work yet)
#   warnings.warn(

# %%
output = simulation.run(n_steps=2250, steps_per_output_interval=10)

# %%
figure(output, settings, simulation)
show_plot("Fig_4.pdf")
# Out:
# HTML(value="<a href='./Fig_4.pdf' target='_blank'>./Fig_4.pdf</a><br>")
