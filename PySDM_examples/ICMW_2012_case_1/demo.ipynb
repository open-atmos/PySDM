# %%
# %run demo_impl.ipynb
# Out:
# Widget Javascript not detected.  It may not be installed or enabled properly.
# /home/slayoo/devel/PySDM/PySDM_examples/ICMW_2012_case_1/../../submodules/MPyDATA/MPyDATA/mpdata.py:40: NumbaWarning:
# Compilation is falling back to object mode WITH looplifting enabled because Function "step" failed type inference due to: non-precise type pyobject
# [1] During: typing of argument at /home/slayoo/devel/PySDM/PySDM_examples/ICMW_2012_case_1/../../submodules/MPyDATA/MPyDATA/mpdata.py (42)
#
# File "../../submodules/MPyDATA/MPyDATA/mpdata.py", line 42:
#     def step(self, n_iters, mu=0.):
#         assert n_iters > 0
#         ^
#
#   @numba.jit()
# /home/slayoo/devel/PySDM/PySDM_examples/ICMW_2012_case_1/../../submodules/MPyDATA/MPyDATA/mpdata.py:40: NumbaWarning:
# Compilation is falling back to object mode WITHOUT looplifting enabled because Function "step" failed type inference due to: Unsupported constraint encountered: raise $10load_global.0
#
# ...
